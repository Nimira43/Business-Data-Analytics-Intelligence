# %% [markdown]
# <a href="https://colab.research.google.com/github/Nimira43/Business-Data-Analytics-Intelligence/blob/main/Basic_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Basic Statistics

# %%
#change directory
# %cd /content/drive/MyDrive/Colab Notebooks/Business Data Analytics/01-Basic-Statistics
# Out:
# /content/drive/MyDrive/Colab Notebooks/Business Data Analytics/01-Basic-Statistics

# %%
#libraries
import pandas as pd
import seaborn as sns

# %%
#dataset
df = pd.read_csv('Baseball.csv')
df.head()
# Out:
#   Team League  Year   RS   RA   W    OBP    SLG     BA  Playoffs  RankSeason  \
# 0  ARI     NL  2012  734  688  81  0.328  0.418  0.259         0         NaN
# 1  ATL     NL  2012  700  600  94  0.320  0.389  0.247         1         4.0
# 2  BAL     AL  2012  712  705  93  0.311  0.417  0.247         1         5.0
# 3  BOS     AL  2012  734  806  69  0.315  0.415  0.260         0         NaN
# 4  CHC     NL  2012  613  759  61  0.302  0.378  0.240         0         NaN
#
#    RankPlayoffs    G   OOBP   OSLG
# 0           NaN  162  0.317  0.415
# 1           5.0  162  0.306  0.378
# 2           4.0  162  0.315  0.403
# 3           NaN  162  0.331  0.428
# 4           NaN  162  0.335  0.424

# %% [markdown]
# ##Mean

# %%
#Mean of runs scored - rs
df.RS.mean()
# Out:
# 715.0819805194806

# %%
#Arizona data
df.loc[df.Team == 'ARI']
# Out:
#     Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 0    ARI     NL  2012  734  688   81  0.328  0.418  0.259         0
# 30   ARI     NL  2011  731  662   94  0.322  0.413  0.250         1
# 60   ARI     NL  2010  713  836   65  0.325  0.416  0.250         0
# 90   ARI     NL  2009  720  782   70  0.324  0.418  0.253         0
# 120  ARI     NL  2008  720  706   82  0.327  0.415  0.251         0
# 150  ARI     NL  2007  712  732   90  0.321  0.413  0.250         1
# 180  ARI     NL  2006  773  788   76  0.331  0.424  0.267         0
# 210  ARI     NL  2005  696  856   77  0.332  0.421  0.256         0
# 241  ARI     NL  2004  615  899   51  0.310  0.393  0.253         0
# 271  ARI     NL  2003  717  685   84  0.330  0.417  0.263         0
# 301  ARI     NL  2002  819  674   98  0.346  0.423  0.267         1
# 331  ARI     NL  2001  818  677   92  0.341  0.442  0.267         1
# 361  ARI     NL  2000  792  754   85  0.333  0.429  0.265         0
# ...

# %%
#Mean of runs scored - rs - Arizona
df.loc[df.Team == 'ARI'].RS.mean()
# Out:
# 742.2

# %%
#Arizona - since 2005
df.loc[(df.Team == 'ARI') & (df.Year > 2005)]
# Out:
#     Team League  Year   RS   RA   W    OBP    SLG     BA  Playoffs  \
# 0    ARI     NL  2012  734  688  81  0.328  0.418  0.259         0
# 30   ARI     NL  2011  731  662  94  0.322  0.413  0.250         1
# 60   ARI     NL  2010  713  836  65  0.325  0.416  0.250         0
# 90   ARI     NL  2009  720  782  70  0.324  0.418  0.253         0
# 120  ARI     NL  2008  720  706  82  0.327  0.415  0.251         0
# 150  ARI     NL  2007  712  732  90  0.321  0.413  0.250         1
# 180  ARI     NL  2006  773  788  76  0.331  0.424  0.267         0
#
#      RankSeason  RankPlayoffs    G   OOBP   OSLG
# 0           NaN           NaN  162  0.317  0.415
# 30          5.0           4.0  162  0.316  0.409
# 60          NaN           NaN  162  0.340  0.448
# 90          NaN           NaN  162  0.330  0.419
# 120         NaN           NaN  162  0.318  0.398
# 150         3.0           3.0  162  0.334  0.420
# 180         NaN           NaN  162  0.335  0.431

# %%
#Mean of runs scored - rs - Arizona - since 2005
df.loc[(df.Team == 'ARI') & (df.Year > 2005)].RS.mean()
# Out:
# 729.0

# %%
#Chicago data
df.loc[df.Team == 'CHC']
# Out:
#      Team League  Year   RS   RA   W    OBP    SLG     BA  Playoffs  \
# 4     CHC     NL  2012  613  759  61  0.302  0.378  0.240         0
# 34    CHC     NL  2011  654  756  71  0.314  0.401  0.256         0
# 64    CHC     NL  2010  685  767  75  0.320  0.401  0.257         0
# 94    CHC     NL  2009  707  672  83  0.332  0.407  0.255         0
# 124   CHC     NL  2008  855  671  97  0.354  0.443  0.278         1
# 154   CHC     NL  2007  752  690  85  0.333  0.422  0.271         1
# 184   CHC     NL  2006  716  834  66  0.319  0.422  0.268         0
# 214   CHC     NL  2005  703  714  79  0.324  0.440  0.270         0
# 245   CHC     NL  2004  789  665  89  0.328  0.458  0.268         0
# 275   CHC     NL  2003  724  683  88  0.323  0.416  0.259         1
# 305   CHC     NL  2002  706  759  67  0.321  0.413  0.246         0
# 335   CHC     NL  2001  777  701  88  0.336  0.430  0.261         0
# 365   CHC     NL  2000  764  904  65  0.335  0.411  0.256         0
# ...

# %%
#Mean of runs scored - rs - Chicago
df.loc[df.Team == 'CHC'].RS.mean()
# Out:
# 695.1914893617021

# %%
#Mean of runs scored - rs - Chicago - since 2005
df.loc[(df.Team == 'CHC') & (df.Year > 1971)].RS.mean()
# Out:
# 704.5135135135135

# %%
# Exercise - What is mean of RA by Chicago until 2007?
df.loc[(df.Team == 'CHC') & (df.Year < 2007)].RA.mean()
# Out:
# 728.170731707317

# %% [markdown]
# ##Mode

# %%
#Most frequent number
#Comparing Mean Median and Mode - Wins
print(df.W.mean())
print(df.W.median())
print(df.W.mode())
# Out:
# 80.90422077922078
# 81.0
# 0    83
# Name: W, dtype: int64

# %%
#Comparing Mean Median and Mode - OBP (On base percentage)
print(df.OBP.mean())
print(df.OBP.median())
print(df.OBP.mode())
# Out:
# 0.32633116883116886
# 0.326
# 0    0.322
# Name: OBP, dtype: float64

# %%
#Exercise: What is the OBP during the year 2010?
df.loc[df.Year == 2010].OBP.mode()
# Out:
# 0    0.332
# Name: OBP, dtype: float64

# %% [markdown]
# ##Median

# %%
#Central number
#Comparing Mean, Mode and Median
print(df.W.mean())
print(df.W.mode())
print(df.W.median())
# Out:
# 80.90422077922078
# 0    83
# Name: W, dtype: int64
# 81.0

# %%
#Exercise - What is median of wins of Baltimore (BAL) until 2000?
df.loc[(df.Team == 'BAL') & (df.Year <= 2000)].W.median()
# Out:
# 89.0

# %% [markdown]
# ##Correlation

# %% [markdown]
# 1.   Measures the relationship strength between two variables
# 2.   Varies between -1 and 1
# 3.   1 means a strong positive relationship
# 4.   -1 means a strong negative relationship
# 5.   0 indicates no relationship
# 6.   Correlation does not imply causation - see https://www.tylervigen.com/spurious-correlations
#
# ![Correlation-Formula.jpg](data:image/jpeg;base64,...)

# %%
#Variables
df_correlation = df[['RS', 'RA', 'W']]
df_correlation.head(1)
# Out:
#     RS   RA   W
# 0  734  688  81

# %%
#Correlation matrix
df_correlation.corr()
# Out:
#           RS        RA         W
# RS  1.000000  0.380139  0.511745
# RA  0.380139  1.000000 -0.532394
# W   0.511745 -0.532394  1.000000

# %% [markdown]
# 1.   RS & RA - Positive correlation
# 2.   RS & W - Positive correlation
# 3.   RA & W - Negative correlation

# %%
#Correlation Heatmap
sns.heatmap(data = df_correlation.corr(),
            )
# Out:
# <Axes: >

# %%
sns.heatmap(data = df_correlation.corr(),
            annot = True,
            fmt = '.2g')
# Out:
# <Axes: >

# %%
sns.heatmap(data = df_correlation.corr(),
            annot = True,
            fmt = '.2g',
            center = 0)
# Out:
# <Axes: >

# %%
sns.heatmap(data = df_correlation.corr(),
            annot = True,
            fmt = '.2g',
            center = 0,
            cmap = 'coolwarm',
            linewidth = 1,
            linecolor = 'black')
# Out:
# <Axes: >

# %%
#Exercise - Correlation matrix between OBP, SLG and BA. With a heatmap with two parameters changed
