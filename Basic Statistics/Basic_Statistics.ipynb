# %% [markdown]
# <a href="https://colab.research.google.com/github/Nimira43/Business-Data-Analytics-Intelligence/blob/main/Basic%20Statistics/Basic_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries, Directory & Data

# %%
#change directory
# %cd /content/drive/MyDrive/COMPUTER SCIENCES/ZTM/BUSINESS DATA ANALYTICS/Statistics and Descriptive Analytics/Basic Statistics
# Out:
# /content/drive/MyDrive/COMPUTER SCIENCES/ZTM/BUSINESS DATA ANALYTICS/Statistics and Descriptive Analytics/Basic Statistics

# %%
#Libraries
import pandas as pd
import seaborn as sns

# %%
#Load the dataset
df = pd.read_csv("Baseball.csv")
df.head()
# Out:
#   Team League  Year   RS   RA   W    OBP    SLG     BA  Playoffs  RankSeason  \
# 0  ARI     NL  2012  734  688  81  0.328  0.418  0.259         0         NaN
# 1  ATL     NL  2012  700  600  94  0.320  0.389  0.247         1         4.0
# 2  BAL     AL  2012  712  705  93  0.311  0.417  0.247         1         5.0
# 3  BOS     AL  2012  734  806  69  0.315  0.415  0.260         0         NaN
# 4  CHC     NL  2012  613  759  61  0.302  0.378  0.240         0         NaN
#
#    RankPlayoffs    G   OOBP   OSLG
# 0           NaN  162  0.317  0.415
# 1           5.0  162  0.306  0.378
# 2           4.0  162  0.315  0.403
# 3           NaN  162  0.331  0.428
# 4           NaN  162  0.335  0.424

# %% [markdown]
# Test - send to Github

# %% [markdown]
# ##Mean

# %%
#Mean of runs scored (RS)
df.RS.mean()
# Out:
# 715.0819805194806

# %%
#Runs scored (RS) by BOS - Boston
df.loc[df.Team == "BOS"]
# Out:
#      Team League  Year   RS   RA   W    OBP    SLG     BA  Playoffs  \
# 3     BOS     AL  2012  734  806  69  0.315  0.415  0.260         0
# 33    BOS     AL  2011  875  737  90  0.349  0.461  0.280         0
# 63    BOS     AL  2010  818  744  89  0.339  0.451  0.268         0
# 93    BOS     AL  2009  872  736  95  0.352  0.454  0.270         1
# 123   BOS     AL  2008  845  694  95  0.358  0.447  0.280         1
# 153   BOS     AL  2007  867  657  96  0.362  0.444  0.279         1
# 183   BOS     AL  2006  820  825  86  0.351  0.435  0.269         0
# 213   BOS     AL  2005  910  805  95  0.357  0.454  0.281         1
# 244   BOS     AL  2004  949  768  98  0.360  0.472  0.282         1
# 274   BOS     AL  2003  961  809  95  0.360  0.491  0.289         1
# 304   BOS     AL  2002  859  665  93  0.345  0.444  0.277         0
# 334   BOS     AL  2001  772  745  82  0.334  0.439  0.266         0
# 364   BOS     AL  2000  792  745  85  0.341  0.423  0.267         0
# ...

# %%
#Mean Runs scored (RS) by BOS - Boston
df.loc[df.Team == "BOS"].RS.mean()
# Out:
# 781.4893617021277

# %%
#Mean Runs scored (RS) by AZI - Arizona
df.loc[df.Team == "ARI"].RS.mean()
# Out:
# 742.2

# %%
#Runs scored (RS) by BOS since 2002
df.loc[(df.Team == "BOS") & (df.Year > 2002) ]
# Out:
#     Team League  Year   RS   RA   W    OBP    SLG     BA  Playoffs  \
# 3    BOS     AL  2012  734  806  69  0.315  0.415  0.260         0
# 33   BOS     AL  2011  875  737  90  0.349  0.461  0.280         0
# 63   BOS     AL  2010  818  744  89  0.339  0.451  0.268         0
# 93   BOS     AL  2009  872  736  95  0.352  0.454  0.270         1
# 123  BOS     AL  2008  845  694  95  0.358  0.447  0.280         1
# 153  BOS     AL  2007  867  657  96  0.362  0.444  0.279         1
# 183  BOS     AL  2006  820  825  86  0.351  0.435  0.269         0
# 213  BOS     AL  2005  910  805  95  0.357  0.454  0.281         1
# 244  BOS     AL  2004  949  768  98  0.360  0.472  0.282         1
# 274  BOS     AL  2003  961  809  95  0.360  0.491  0.289         1
#
#      RankSeason  RankPlayoffs    G   OOBP   OSLG
# 3           NaN           NaN  162  0.331  0.428
# 33          NaN           NaN  162  0.322  0.392
# 63          NaN           NaN  162  0.327  0.399
# ...

# %%
#Mean number of Runs scored (RS) by BOS since 2002
df.loc[(df.Team == "BOS") & (df.Year > 2002) ].RS.mean()
# Out:
# 865.1

# %%
#Mean of Runs Allowed (RA) for CHC - Chicargo until 2007
df.loc[(df.Team == "CHC") & (df.Year < 2007)].RA.mean()
# Out:
# 728.170731707317
